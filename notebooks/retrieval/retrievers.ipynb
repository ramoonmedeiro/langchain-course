# %% [markdown]
# # Aqui estará as explicações de como criar RAGs e como elas funcionam.

# %%
import os
from dotenv import find_dotenv, load_dotenv

load_dotenv(find_dotenv())

groq_api_key = os.getenv("GROQ_API_KEY")

from langchain_groq import ChatGroq

llm = ChatGroq(
    model="llama3-8b-8192",
    temperature=0,
    max_tokens=None,
    timeout=None,
    max_retries=2,
)

# %% [markdown]
# # Usando um arquivo CSV

# %%
from langchain.document_loaders import CSVLoader

csv_file_path = "../../dataset/movies.csv"

csv_loader = CSVLoader(file_path=csv_file_path,  csv_args={'delimiter': ','})
data = csv_loader.load()

# %%
data
# Out:
# [Document(metadata={'source': '../../dataset/movies.csv', 'row': 0}, page_content='\ufeffTitle: Avatar: The Way of Water\nRating: 7.8\nYear: 2022\nMonth: December\nCertificate: PG-13\nRuntime: 192\nDirectors: James Cameron\nStars: Sam Worthington, Zoe Saldana, Sigourney Weaver, Stephen Lang\nGenre: Action, Adventure, Fantasy\nFilming_location: New Zealand\nBudget: $350,000,000\nIncome: $2,267,946,983\nCountry_of_origin: United States'),
#  Document(metadata={'source': '../../dataset/movies.csv', 'row': 1}, page_content="\ufeffTitle: Guillermo del Toro's Pinocchio\nRating: 7.6\nYear: 2022\nMonth: December\nCertificate: PG\nRuntime: 117\nDirectors: Guillermo del Toro, Mark Gustafson\nStars: Ewan McGregor, David Bradley, Gregory Mann, Burn Gorman\nGenre: Animation, Drama, Family\nFilming_location: USA\nBudget: $35,000,000\nIncome: $108,967\nCountry_of_origin: United States, Mexico, France"),
# ...

# %%
# Pegando a primeira linha
print(data[0].page_content)
# Out:
# Title: Avatar: The Way of Water
# Rating: 7.8
# Year: 2022
# Month: December
# Certificate: PG-13
# Runtime: 192
# Directors: James Cameron
# Stars: Sam Worthington, Zoe Saldana, Sigourney Weaver, Stephen Lang
# Genre: Action, Adventure, Fantasy
# Filming_location: New Zealand
# Budget: $350,000,000
# Income: $2,267,946,983
# Country_of_origin: United States
